# %% [markdown]
# https://python.langchain.com/v0.2/docs/integrations/tools/bash/

# %%
# !pip install langchain-community
# !pip install langchain-experimental
# Out:
# Looking in indexes: https://edge.artifactory.corp.yahoo.co.jp:4443/artifactory/api/pypi/apj-pypi/simple
# ...
#
# [notice] A new release of pip is available: 23.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://edge.artifactory.corp.yahoo.co.jp:4443/artifactory/api/pypi/apj-pypi/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.7/202.7 kB 2.7 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

# %%
result = shell_tool.run({"commands": ["echo 'Hello World!'"]})
# Out:
# Executing command:
#  ["echo 'Hello World!'"]
# /Users/rhirabay/.local/share/virtualenvs/openai-YWi3lsqc/lib/python3.11/site-packages/langchain_community/tools/shell/tool.py:32: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %%
print(result)
# Out:
# Hello World!

# %%
result = shell_tool.run({"commands": ["read N"]})
# Out:
# Executing command:
#  ['read N']
# /Users/rhirabay/.local/share/virtualenvs/openai-YWi3lsqc/lib/python3.11/site-packages/langchain_community/tools/shell/tool.py:32: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %%
print(result)
